# %%
# !pip install -U tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.20.0 typeguard-2.13.3

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras
from tensorflow.keras import layers
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from tensorflow.keras.preprocessing import image
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
target_size = (32, 32)

def resize_images(img):
    img_pil = image.array_to_img(img)
    img_resized = img_pil.resize(target_size)
    img_resized_np = image.img_to_array(img_resized)
    return img_resized_np
# Reshape the training dataset
train_generator = ImageDataGenerator(rescale=1./255., preprocessing_function=resize_images)
train = train_generator.flow_from_directory(
    '/content/drive/MyDrive/Vision_Transformer/butterly_dataset/train',
    batch_size=20,
    class_mode='categorical',
    target_size=target_size
)

# Reshape the validation dataset
valid_generator = ImageDataGenerator(rescale=1./255., preprocessing_function=resize_images)
valid = valid_generator.flow_from_directory(
    '/content/drive/MyDrive/Vision_Transformer/butterly_dataset/valid',
    batch_size=20,
    class_mode='categorical',
    target_size=target_size
)

# Reshape the test dataset
test_generator = ImageDataGenerator(rescale=1./255., preprocessing_function=resize_images)
test = test_generator.flow_from_directory(
    '/content/drive/MyDrive/Vision_Transformer/butterly_dataset/test',
    batch_size=20,
    class_mode='categorical',
    target_size=target_size
)
# Out:
# Found 12594 images belonging to 100 classes.
# Found 500 images belonging to 100 classes.
# Found 500 images belonging to 100 classes.

# %%
patch_size = (2, 2)  # 2-by-2 sized patches
dropout_rate = 0.03  # Dropout rate
num_heads = 8  # Attention heads
embed_dim = 448  # Embedding dimension
num_mlp = 256  # MLP layer size
qkv_bias = True  # Convert embedded patches to query, key, and values with a learnable additive value
window_size = 2  # Size of attention window
shift_size = 1  # Size of shifting window
image_dimension = 32  # Initial image size
input_shape =(32,32,3)
num_patch_x = input_shape[0] // patch_size[0]
num_patch_y = input_shape[1] // patch_size[1]
print(num_patch_x)
print(num_patch_y)

learning_rate = 1e-3
batch_size = 128
num_epochs = 100
validation_split = 0.1
weight_decay = 0.0001
label_smoothing = 0.1
# Out:
# 16
# 16

# %%
def window_partition(x, window_size):
    _, height, width, channels = x.shape
    patch_num_y = height // window_size
    patch_num_x = width // window_size
    x = tf.reshape(
        x, shape=(-1, patch_num_y, window_size, patch_num_x, window_size, channels)
    )
    x = tf.transpose(x, (0, 1, 3, 2, 4, 5))
    windows = tf.reshape(x, shape=(-1, window_size, window_size, channels))
    return windows


def window_reverse(windows, window_size, height, width, channels):
    patch_num_y = height // window_size
    patch_num_x = width // window_size
    x = tf.reshape(
        windows,
        shape=(-1, patch_num_y, patch_num_x, window_size, window_size, channels),
    )
    x = tf.transpose(x, perm=(0, 1, 3, 2, 4, 5))
    x = tf.reshape(x, shape=(-1, height, width, channels))
    return x


class DropPath(layers.Layer):
    def __init__(self, drop_prob=None, **kwargs):
        super().__init__(**kwargs)
        self.drop_prob = drop_prob

    def call(self, x):
        input_shape = tf.shape(x)
        batch_size = input_shape[0]
        rank = x.shape.rank
        shape = (batch_size,) + (1,) * (rank - 1)
        random_tensor = (1 - self.drop_prob) + tf.random.uniform(shape, dtype=x.dtype)
        path_mask = tf.floor(random_tensor)
        output = tf.math.divide(x, 1 - self.drop_prob) * path_mask
        return output

# %%
class WindowAttention(layers.Layer):
    def __init__(
        self, dim, window_size, num_heads, qkv_bias=True, dropout_rate=0.0, **kwargs
    ):
        super().__init__(**kwargs)
        self.dim = dim
        self.window_size = window_size
        self.num_heads = num_heads
        self.scale = (dim // num_heads) ** -0.5
        self.qkv = layers.Dense(dim * 3, use_bias=qkv_bias)
        self.dropout = layers.Dropout(dropout_rate)
        self.proj = layers.Dense(dim)

    def build(self, input_shape):
        num_window_elements = (2 * self.window_size[0] - 1) * (
            2 * self.window_size[1] - 1
        )
        self.relative_position_bias_table = self.add_weight(
            shape=(num_window_elements, self.num_heads),
            initializer=tf.initializers.Zeros(),
            trainable=True,
        )
        coords_h = np.arange(self.window_size[0])
        coords_w = np.arange(self.window_size[1])
        coords_matrix = np.meshgrid(coords_h, coords_w, indexing="ij")
        coords = np.stack(coords_matrix)
        coords_flatten = coords.reshape(2, -1)
        relative_coords = coords_flatten[:, :, None] - coords_flatten[:, None, :]
        relative_coords = relative_coords.transpose([1, 2, 0])
        relative_coords[:, :, 0] += self.window_size[0] - 1
        relative_coords[:, :, 1] += self.window_size[1] - 1
        relative_coords[:, :, 0] *= 2 * self.window_size[1] - 1
        relative_position_index = relative_coords.sum(-1)

        self.relative_position_index = tf.Variable(
            initial_value=tf.convert_to_tensor(relative_position_index), trainable=False
        )

    def call(self, x, mask=None):
        _, size, channels = x.shape
        head_dim = channels // self.num_heads
        x_qkv = self.qkv(x)
        x_qkv = tf.reshape(x_qkv, shape=(-1, size, 3, self.num_heads, head_dim))
        x_qkv = tf.transpose(x_qkv, perm=(2, 0, 3, 1, 4))
        q, k, v = x_qkv[0], x_qkv[1], x_qkv[2]
        q = q * self.scale
        k = tf.transpose(k, perm=(0, 1, 3, 2))
        attn = q @ k

        num_window_elements = self.window_size[0] * self.window_size[1]
        relative_position_index_flat = tf.reshape(
            self.relative_position_index, shape=(-1,)
        )
        relative_position_bias = tf.gather(
            self.relative_position_bias_table, relative_position_index_flat
        )
        relative_position_bias = tf.reshape(
            relative_position_bias, shape=(num_window_elements, num_window_elements, -1)
        )
        relative_position_bias = tf.transpose(relative_position_bias, perm=(2, 0, 1))
        attn = attn + tf.expand_dims(relative_position_bias, axis=0)

        if mask is not None:
            nW = mask.get_shape()[0]
            mask_float = tf.cast(
                tf.expand_dims(tf.expand_dims(mask, axis=1), axis=0), tf.float32
            )
            attn = (
                tf.reshape(attn, shape=(-1, nW, self.num_heads, size, size))
                + mask_float
            )
            attn = tf.reshape(attn, shape=(-1, self.num_heads, size, size))
            attn = keras.activations.softmax(attn, axis=-1)
        else:
            attn = keras.activations.softmax(attn, axis=-1)
        attn = self.dropout(attn)

        x_qkv = attn @ v
        x_qkv = tf.transpose(x_qkv, perm=(0, 2, 1, 3))
        x_qkv = tf.reshape(x_qkv, shape=(-1, size, channels))
        x_qkv = self.proj(x_qkv)
        x_qkv = self.dropout(x_qkv)
        return x_qkv

# %%
class SwinTransformer(layers.Layer):
    def __init__(
        self,
        dim,
        num_patch,
        num_heads,
        window_size=7,
        shift_size=0,
        num_mlp=1024,
        qkv_bias=True,
        dropout_rate=0.0,
        **kwargs,
    ):
        super().__init__(**kwargs)

        self.dim = dim  # number of input dimensions
        self.num_patch = num_patch  # number of embedded patches
        self.num_heads = num_heads  # number of attention heads
        self.window_size = window_size  # size of window
        self.shift_size = shift_size  # size of window shift
        self.num_mlp = num_mlp  # number of MLP nodes

        self.norm1 = layers.LayerNormalization(epsilon=1e-5)
        self.attn = WindowAttention(
            dim,
            window_size=(self.window_size, self.window_size),
            num_heads=num_heads,
            qkv_bias=qkv_bias,
            dropout_rate=dropout_rate,
        )
        self.drop_path = DropPath(dropout_rate)
        self.norm2 = layers.LayerNormalization(epsilon=1e-5)

        self.mlp = keras.Sequential(
            [
                layers.Dense(num_mlp),
                layers.Activation(keras.activations.gelu),
                layers.Dropout(dropout_rate),
                layers.Dense(dim),
                layers.Dropout(dropout_rate),
            ]
        )

        if min(self.num_patch) < self.window_size:
            self.shift_size = 0
            self.window_size = min(self.num_patch)

    def build(self, input_shape):
        if self.shift_size == 0:
            self.attn_mask = None
        else:
            height, width = self.num_patch
            h_slices = (
                slice(0, -self.window_size),
                slice(-self.window_size, -self.shift_size),
                slice(-self.shift_size, None),
            )
            w_slices = (
                slice(0, -self.window_size),
                slice(-self.window_size, -self.shift_size),
                slice(-self.shift_size, None),
            )
            mask_array = np.zeros((1, height, width, 1))
            count = 0
            for h in h_slices:
                for w in w_slices:
                    mask_array[:, h, w, :] = count
                    count += 1
            mask_array = tf.convert_to_tensor(mask_array)

            # mask array to windows
            mask_windows = window_partition(mask_array, self.window_size)
            mask_windows = tf.reshape(
                mask_windows, shape=[-1, self.window_size * self.window_size]
            )
            attn_mask = tf.expand_dims(mask_windows, axis=1) - tf.expand_dims(
                mask_windows, axis=2
            )
            attn_mask = tf.where(attn_mask != 0, -100.0, attn_mask)
            attn_mask = tf.where(attn_mask == 0, 0.0, attn_mask)
            self.attn_mask = tf.Variable(initial_value=attn_mask, trainable=False)

    def call(self, x):
        height, width = self.num_patch
        _, num_patches_before, channels = x.shape
        x_skip = x
        x = self.norm1(x)
        x = tf.reshape(x, shape=(-1, height, width, channels))
        if self.shift_size > 0:
            shifted_x = tf.roll(
                x, shift=[-self.shift_size, -self.shift_size], axis=[1, 2]
            )
        else:
            shifted_x = x

        x_windows = window_partition(shifted_x, self.window_size)
        x_windows = tf.reshape(
            x_windows, shape=(-1, self.window_size * self.window_size, channels)
        )
        attn_windows = self.attn(x_windows, mask=self.attn_mask)

        attn_windows = tf.reshape(
            attn_windows, shape=(-1, self.window_size, self.window_size, channels)
        )
        shifted_x = window_reverse(
            attn_windows, self.window_size, height, width, channels
        )
        if self.shift_size > 0:
            x = tf.roll(
                shifted_x, shift=[self.shift_size, self.shift_size], axis=[1, 2]
            )
        else:
            x = shifted_x

        x = tf.reshape(x, shape=(-1, height * width, channels))
        x = self.drop_path(x)
        x = x_skip + x
        x_skip = x
        x = self.norm2(x)
        x = self.mlp(x)
        x = self.drop_path(x)
        x = x_skip + x
        return x

# %%
class PatchExtract(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size_x = patch_size[0]
        self.patch_size_y = patch_size[1]

    def call(self, images):
        batch_size = tf.shape(images)[0]
        input_shape = tf.shape(images)[1:3]
        patch_num_x = input_shape[0] // self.patch_size_x
        patch_num_y = input_shape[1] // self.patch_size_y
        patches = tf.image.extract_patches(
            images=images,
            sizes=(1, self.patch_size_x, self.patch_size_y, 1),
            strides=(1, self.patch_size_x, self.patch_size_y, 1),
            rates=(1, 1, 1, 1),
            padding="VALID",
        )
        patch_dim = tf.shape(patches)[-1]
        patches = tf.reshape(patches, (batch_size, patch_num_x * patch_num_y, patch_dim))
        return patches




class PatchEmbedding(layers.Layer):
    def __init__(self, num_patch, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patch = num_patch
        self.proj = layers.Dense(embed_dim)
        self.pos_embed = layers.Embedding(input_dim=num_patch, output_dim=embed_dim)

    def call(self, patch):
      pos = tf.range(start=0, limit=self.num_patch, delta=1)
      pos_embedded = self.pos_embed(pos)  # Shape: (num_patch, embed_dim)
      pos_embedded = tf.expand_dims(pos_embedded, axis=0)  # Shape: (1, num_patch, embed_dim)
      pos_embedded = tf.repeat(pos_embedded, tf.shape(patch)[0], axis=0)  # Repeat for batch dimension
      return self.proj(patch) + pos_embedded


class PatchMerging(tf.keras.layers.Layer):
    def __init__(self, num_patch, embed_dim):
        super().__init__()
        self.num_patch = num_patch
        self.embed_dim = embed_dim
        self.linear_trans = layers.Dense(2 * embed_dim, use_bias=False)

    def call(self, x):
        height, width = self.num_patch
        _, _, C = x.get_shape().as_list()
        x = tf.reshape(x, shape=(-1, height, width, C))
        x0 = x[:, 0::2, 0::2, :]
        x1 = x[:, 1::2, 0::2, :]
        x2 = x[:, 0::2, 1::2, :]
        x3 = x[:, 1::2, 1::2, :]
        x = tf.concat((x0, x1, x2, x3), axis=-1)
        x = tf.reshape(x, shape=(-1, (height // 2) * (width // 2), 4 * C))
        return self.linear_trans(x)

# %%
num_classes=100

# %%
input = layers.Input(shape=(32,32, 3))
x = layers.RandomCrop(image_dimension, image_dimension)(input)
x = layers.RandomFlip("horizontal")(x)
x = PatchExtract(patch_size)(x)
x = PatchEmbedding(num_patch_x * num_patch_y, embed_dim)(x)
x = SwinTransformer(
    dim=embed_dim,
    num_patch=(num_patch_x, num_patch_y),
    num_heads=num_heads,
    window_size=window_size,
    shift_size=0,
    num_mlp=num_mlp,
    qkv_bias=qkv_bias,
    dropout_rate=dropout_rate,
)(x)
x = SwinTransformer(
    dim=embed_dim,
    num_patch=(num_patch_x, num_patch_y),
    num_heads=num_heads,
    window_size=window_size,
    shift_size=shift_size,
    num_mlp=num_mlp,
    qkv_bias=qkv_bias,
    dropout_rate=dropout_rate,
)(x)
x = PatchMerging((num_patch_x, num_patch_y), embed_dim=embed_dim)(x)
x = layers.GlobalAveragePooling1D()(x)
output = layers.Dense(num_classes, activation="softmax")(x)

# %%
model = keras.Model(input, output)
model.compile(
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=label_smoothing),
    optimizer=tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    ),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.TopKCategoricalAccuracy(5, name="top-5-accuracy"),
    ],
)

history = model.fit(
    train,
    validation_data=valid,
    batch_size=batch_size,
    epochs=num_epochs,
)
# Out:
# Epoch 1/100
# 630/630 [==============================] - 4551s 7s/step - loss: 5.0404 - accuracy: 0.1089 - top-5-accuracy: 0.3074 - val_loss: 3.5639 - val_accuracy: 0.1920 - val_top-5-accuracy: 0.4920
# Epoch 2/100
# 630/630 [==============================] - 51s 80ms/step - loss: 3.3279 - accuracy: 0.2553 - top-5-accuracy: 0.5680 - val_loss: 2.9445 - val_accuracy: 0.3600 - val_top-5-accuracy: 0.6920
# Epoch 3/100
# 630/630 [==============================] - 52s 83ms/step - loss: 3.0421 - accuracy: 0.3307 - top-5-accuracy: 0.6548 - val_loss: 2.8369 - val_accuracy: 0.4060 - val_top-5-accuracy: 0.7140
# Epoch 4/100
# 630/630 [==============================] - 52s 83ms/step - loss: 2.8763 - accuracy: 0.3717 - top-5-accuracy: 0.7062 - val_loss: 2.6147 - val_accuracy: 0.4440 - val_top-5-accuracy: 0.7740
# Epoch 5/100
# 630/630 [==============================] - 51s 82ms/step - loss: 2.7747 - accuracy: 0.4012 - top-5-accuracy: 0.7294 - val_loss: 2.6882 - val_accuracy: 0.4660 - val_top-5-accuracy: 0.7440
# Epoch 6/100
# 630/630 [==============================] - 53s 84ms/step - loss: 2.6982 - accuracy: 0.4278 - top-5-accuracy: 0.7527 - val_loss: 2.5179 - val_accuracy: 0.4740 - val_top-5-accuracy: 0.8100
# Epoch 7/100
# 630/630 [==============================] - 53s 84ms/step - loss: 2.6230 - accuracy: 0.4532 - top-5-accuracy: 0.7672 - val_loss: 2.4785 - val_accuracy: 0.5280 - val_top-5-accuracy: 0.8180
# Epoch 8/100
# 630/630 [==============================] - 53s 84ms/step - loss: 2.5495 - accuracy: 0.4703 - top-5-accuracy: 0.7883 - val_loss: 2.4780 - val_accuracy: 0.4980 - val_top-5-accuracy: 0.8180
# Epoch 9/100
# 630/630 [==============================] - 53s 83ms/step - loss: 2.4814 - accuracy: 0.4941 - top-5-accuracy: 0.8040 - val_loss: 2.4579 - val_accuracy: 0.5040 - val_top-5-accuracy: 0.8220
# Epoch 10/100
# 630/630 [==============================] - 52s 83ms/step - loss: 2.4208 - accuracy: 0.5130 - top-5-accuracy: 0.8144 - val_loss: 2.2768 - val_accuracy: 0.5840 - val_top-5-accuracy: 0.8400
# Epoch 11/100
# 630/630 [==============================] - 51s 81ms/step - loss: 2.3742 - accuracy: 0.5258 - top-5-accuracy: 0.8241 - val_loss: 2.2268 - val_accuracy: 0.5840 - val_top-5-accuracy: 0.8420
# Epoch 12/100
# 630/630 [==============================] - 55s 88ms/step - loss: 2.3232 - accuracy: 0.5405 - top-5-accuracy: 0.8379 - val_loss: 2.2457 - val_accuracy: 0.5660 - val_top-5-accuracy: 0.8660
# Epoch 13/100
# 630/630 [==============================] - 53s 84ms/step - loss: 2.2509 - accuracy: 0.5645 - top-5-accuracy: 0.8504 - val_loss: 2.1553 - val_accuracy: 0.5820 - val_top-5-accuracy: 0.8720
# Epoch 14/100
# 630/630 [==============================] - 51s 81ms/step - loss: 2.2044 - accuracy: 0.5835 - top-5-accuracy: 0.8596 - val_loss: 2.1596 - val_accuracy: 0.6140 - val_top-5-accuracy: 0.8680
# Epoch 15/100
# 630/630 [==============================] - 50s 79ms/step - loss: 2.1811 - accuracy: 0.5892 - top-5-accuracy: 0.8626 - val_loss: 2.1192 - val_accuracy: 0.6080 - val_top-5-accuracy: 0.8820
# Epoch 16/100
# 630/630 [==============================] - 51s 82ms/step - loss: 2.1474 - accuracy: 0.5978 - top-5-accuracy: 0.8696 - val_loss: 2.1307 - val_accuracy: 0.6080 - val_top-5-accuracy: 0.8960
# Epoch 17/100
# 630/630 [==============================] - 51s 82ms/step - loss: 2.1059 - accuracy: 0.6130 - top-5-accuracy: 0.8757 - val_loss: 2.0356 - val_accuracy: 0.6560 - val_top-5-accuracy: 0.8920
# Epoch 18/100
# 630/630 [==============================] - 50s 79ms/step - loss: 2.0684 - accuracy: 0.6232 - top-5-accuracy: 0.8856 - val_loss: 2.0246 - val_accuracy: 0.6700 - val_top-5-accuracy: 0.8920
# Epoch 19/100
# 630/630 [==============================] - 52s 82ms/step - loss: 2.0552 - accuracy: 0.6278 - top-5-accuracy: 0.8846 - val_loss: 1.9750 - val_accuracy: 0.6580 - val_top-5-accuracy: 0.8920
# Epoch 20/100
# 630/630 [==============================] - 51s 81ms/step - loss: 2.0135 - accuracy: 0.6398 - top-5-accuracy: 0.8942 - val_loss: 2.0483 - val_accuracy: 0.6400 - val_top-5-accuracy: 0.8940
# Epoch 21/100
# 630/630 [==============================] - 52s 83ms/step - loss: 2.0001 - accuracy: 0.6436 - top-5-accuracy: 0.8967 - val_loss: 2.1007 - val_accuracy: 0.6500 - val_top-5-accuracy: 0.8920
# Epoch 22/100
# 630/630 [==============================] - 51s 82ms/step - loss: 1.9601 - accuracy: 0.6653 - top-5-accuracy: 0.9019 - val_loss: 2.1109 - val_accuracy: 0.6240 - val_top-5-accuracy: 0.8920
# Epoch 23/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.9431 - accuracy: 0.6648 - top-5-accuracy: 0.9041 - val_loss: 2.0591 - val_accuracy: 0.6640 - val_top-5-accuracy: 0.8920
# Epoch 24/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.9356 - accuracy: 0.6666 - top-5-accuracy: 0.9054 - val_loss: 1.9803 - val_accuracy: 0.6540 - val_top-5-accuracy: 0.9080
# Epoch 25/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.9242 - accuracy: 0.6736 - top-5-accuracy: 0.9100 - val_loss: 1.9844 - val_accuracy: 0.6560 - val_top-5-accuracy: 0.9060
# Epoch 26/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.8818 - accuracy: 0.6879 - top-5-accuracy: 0.9165 - val_loss: 1.9402 - val_accuracy: 0.7000 - val_top-5-accuracy: 0.9020
# Epoch 27/100
# 630/630 [==============================] - 50s 80ms/step - loss: 1.8705 - accuracy: 0.6910 - top-5-accuracy: 0.9153 - val_loss: 1.9363 - val_accuracy: 0.6560 - val_top-5-accuracy: 0.8920
# Epoch 28/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.8647 - accuracy: 0.6917 - top-5-accuracy: 0.9153 - val_loss: 1.9614 - val_accuracy: 0.6640 - val_top-5-accuracy: 0.9120
# Epoch 29/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.8329 - accuracy: 0.7044 - top-5-accuracy: 0.9262 - val_loss: 1.7932 - val_accuracy: 0.7340 - val_top-5-accuracy: 0.9160
# Epoch 30/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.8160 - accuracy: 0.7106 - top-5-accuracy: 0.9258 - val_loss: 1.9169 - val_accuracy: 0.6860 - val_top-5-accuracy: 0.9160
# Epoch 31/100
# 630/630 [==============================] - 50s 79ms/step - loss: 1.8182 - accuracy: 0.7091 - top-5-accuracy: 0.9239 - val_loss: 1.9488 - val_accuracy: 0.6900 - val_top-5-accuracy: 0.8940
# Epoch 32/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.7959 - accuracy: 0.7175 - top-5-accuracy: 0.9270 - val_loss: 1.9037 - val_accuracy: 0.6960 - val_top-5-accuracy: 0.9140
# Epoch 33/100
# 630/630 [==============================] - 51s 80ms/step - loss: 1.7942 - accuracy: 0.7146 - top-5-accuracy: 0.9312 - val_loss: 1.8623 - val_accuracy: 0.6940 - val_top-5-accuracy: 0.9160
# Epoch 34/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.7786 - accuracy: 0.7218 - top-5-accuracy: 0.9321 - val_loss: 1.8455 - val_accuracy: 0.7160 - val_top-5-accuracy: 0.9240
# Epoch 35/100
# 630/630 [==============================] - 50s 80ms/step - loss: 1.7622 - accuracy: 0.7300 - top-5-accuracy: 0.9344 - val_loss: 1.8844 - val_accuracy: 0.7000 - val_top-5-accuracy: 0.9320
# Epoch 36/100
# 630/630 [==============================] - 51s 82ms/step - loss: 1.7700 - accuracy: 0.7209 - top-5-accuracy: 0.9313 - val_loss: 1.9323 - val_accuracy: 0.7140 - val_top-5-accuracy: 0.9040
# Epoch 37/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.7361 - accuracy: 0.7359 - top-5-accuracy: 0.9391 - val_loss: 1.8509 - val_accuracy: 0.7140 - val_top-5-accuracy: 0.9240
# Epoch 38/100
# 630/630 [==============================] - 50s 79ms/step - loss: 1.7363 - accuracy: 0.7358 - top-5-accuracy: 0.9379 - val_loss: 1.8450 - val_accuracy: 0.7260 - val_top-5-accuracy: 0.9060
# Epoch 39/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.7191 - accuracy: 0.7423 - top-5-accuracy: 0.9394 - val_loss: 1.8249 - val_accuracy: 0.7440 - val_top-5-accuracy: 0.9200
# Epoch 40/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.7138 - accuracy: 0.7430 - top-5-accuracy: 0.9403 - val_loss: 1.8738 - val_accuracy: 0.6920 - val_top-5-accuracy: 0.9040
# Epoch 41/100
# 630/630 [==============================] - 51s 80ms/step - loss: 1.7096 - accuracy: 0.7467 - top-5-accuracy: 0.9408 - val_loss: 1.8352 - val_accuracy: 0.7200 - val_top-5-accuracy: 0.9200
# Epoch 42/100
# 630/630 [==============================] - 51s 82ms/step - loss: 1.7050 - accuracy: 0.7512 - top-5-accuracy: 0.9419 - val_loss: 1.8398 - val_accuracy: 0.7100 - val_top-5-accuracy: 0.9280
# Epoch 43/100
# 630/630 [==============================] - 51s 82ms/step - loss: 1.6805 - accuracy: 0.7598 - top-5-accuracy: 0.9462 - val_loss: 1.8084 - val_accuracy: 0.7220 - val_top-5-accuracy: 0.9340
# Epoch 44/100
# 630/630 [==============================] - 50s 80ms/step - loss: 1.6703 - accuracy: 0.7606 - top-5-accuracy: 0.9474 - val_loss: 1.8130 - val_accuracy: 0.7220 - val_top-5-accuracy: 0.9300
# Epoch 45/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.6728 - accuracy: 0.7605 - top-5-accuracy: 0.9480 - val_loss: 1.8973 - val_accuracy: 0.7020 - val_top-5-accuracy: 0.9040
# Epoch 46/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.6625 - accuracy: 0.7656 - top-5-accuracy: 0.9487 - val_loss: 1.7939 - val_accuracy: 0.7320 - val_top-5-accuracy: 0.9340
# Epoch 47/100
# 630/630 [==============================] - 50s 79ms/step - loss: 1.6578 - accuracy: 0.7718 - top-5-accuracy: 0.9501 - val_loss: 1.8612 - val_accuracy: 0.7280 - val_top-5-accuracy: 0.9020
# Epoch 48/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.6627 - accuracy: 0.7628 - top-5-accuracy: 0.9497 - val_loss: 1.8623 - val_accuracy: 0.7100 - val_top-5-accuracy: 0.9160
# Epoch 49/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.6329 - accuracy: 0.7723 - top-5-accuracy: 0.9529 - val_loss: 1.9150 - val_accuracy: 0.7220 - val_top-5-accuracy: 0.9180
# Epoch 50/100
# 630/630 [==============================] - 50s 80ms/step - loss: 1.6371 - accuracy: 0.7739 - top-5-accuracy: 0.9534 - val_loss: 1.8572 - val_accuracy: 0.7120 - val_top-5-accuracy: 0.9120
# Epoch 51/100
# 630/630 [==============================] - 51s 82ms/step - loss: 1.6403 - accuracy: 0.7717 - top-5-accuracy: 0.9505 - val_loss: 1.8274 - val_accuracy: 0.7120 - val_top-5-accuracy: 0.9100
# Epoch 52/100
# 630/630 [==============================] - 53s 84ms/step - loss: 1.6469 - accuracy: 0.7663 - top-5-accuracy: 0.9547 - val_loss: 1.8082 - val_accuracy: 0.7180 - val_top-5-accuracy: 0.9140
# Epoch 53/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.6192 - accuracy: 0.7816 - top-5-accuracy: 0.9536 - val_loss: 1.7701 - val_accuracy: 0.7180 - val_top-5-accuracy: 0.9220
# Epoch 54/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.6105 - accuracy: 0.7832 - top-5-accuracy: 0.9554 - val_loss: 1.8105 - val_accuracy: 0.7260 - val_top-5-accuracy: 0.9180
# Epoch 55/100
# 630/630 [==============================] - 52s 83ms/step - loss: 1.6073 - accuracy: 0.7832 - top-5-accuracy: 0.9564 - val_loss: 1.7970 - val_accuracy: 0.7140 - val_top-5-accuracy: 0.9160
# Epoch 56/100
# 630/630 [==============================] - 50s 79ms/step - loss: 1.6192 - accuracy: 0.7824 - top-5-accuracy: 0.9551 - val_loss: 1.8571 - val_accuracy: 0.6880 - val_top-5-accuracy: 0.9140
# Epoch 57/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.5923 - accuracy: 0.7905 - top-5-accuracy: 0.9571 - val_loss: 1.8823 - val_accuracy: 0.7000 - val_top-5-accuracy: 0.9060
# Epoch 58/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.5915 - accuracy: 0.7871 - top-5-accuracy: 0.9584 - val_loss: 1.9389 - val_accuracy: 0.6980 - val_top-5-accuracy: 0.9080
# Epoch 59/100
# 630/630 [==============================] - 50s 79ms/step - loss: 1.5946 - accuracy: 0.7861 - top-5-accuracy: 0.9587 - val_loss: 1.8201 - val_accuracy: 0.7260 - val_top-5-accuracy: 0.9140
# Epoch 60/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.5899 - accuracy: 0.7929 - top-5-accuracy: 0.9590 - val_loss: 1.8859 - val_accuracy: 0.6900 - val_top-5-accuracy: 0.9040
# Epoch 61/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.5856 - accuracy: 0.7905 - top-5-accuracy: 0.9613 - val_loss: 1.9133 - val_accuracy: 0.6940 - val_top-5-accuracy: 0.9120
# Epoch 62/100
# 630/630 [==============================] - 50s 80ms/step - loss: 1.5645 - accuracy: 0.8041 - top-5-accuracy: 0.9599 - val_loss: 1.8148 - val_accuracy: 0.7260 - val_top-5-accuracy: 0.9240
# Epoch 63/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.5721 - accuracy: 0.7919 - top-5-accuracy: 0.9609 - val_loss: 1.7875 - val_accuracy: 0.7380 - val_top-5-accuracy: 0.9140
# Epoch 64/100
# 630/630 [==============================] - 51s 82ms/step - loss: 1.5488 - accuracy: 0.8050 - top-5-accuracy: 0.9643 - val_loss: 1.8589 - val_accuracy: 0.7280 - val_top-5-accuracy: 0.9060
# Epoch 65/100
# 630/630 [==============================] - 50s 79ms/step - loss: 1.5740 - accuracy: 0.7984 - top-5-accuracy: 0.9570 - val_loss: 1.8312 - val_accuracy: 0.7240 - val_top-5-accuracy: 0.9300
# Epoch 66/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.5696 - accuracy: 0.7920 - top-5-accuracy: 0.9615 - val_loss: 1.9239 - val_accuracy: 0.7120 - val_top-5-accuracy: 0.9080
# Epoch 67/100
# 630/630 [==============================] - 50s 80ms/step - loss: 1.5535 - accuracy: 0.8055 - top-5-accuracy: 0.9643 - val_loss: 1.8335 - val_accuracy: 0.7180 - val_top-5-accuracy: 0.9100
# Epoch 68/100
# 630/630 [==============================] - 52s 83ms/step - loss: 1.5488 - accuracy: 0.8015 - top-5-accuracy: 0.9642 - val_loss: 1.8087 - val_accuracy: 0.7400 - val_top-5-accuracy: 0.9200
# Epoch 69/100
# 630/630 [==============================] - 51s 80ms/step - loss: 1.5516 - accuracy: 0.8000 - top-5-accuracy: 0.9648 - val_loss: 1.8604 - val_accuracy: 0.7080 - val_top-5-accuracy: 0.9120
# Epoch 70/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.5367 - accuracy: 0.8090 - top-5-accuracy: 0.9633 - val_loss: 1.9268 - val_accuracy: 0.7020 - val_top-5-accuracy: 0.9040
# Epoch 71/100
# 630/630 [==============================] - 52s 83ms/step - loss: 1.5310 - accuracy: 0.8139 - top-5-accuracy: 0.9669 - val_loss: 1.8528 - val_accuracy: 0.7260 - val_top-5-accuracy: 0.9180
# Epoch 72/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.5359 - accuracy: 0.8118 - top-5-accuracy: 0.9667 - val_loss: 1.8295 - val_accuracy: 0.6920 - val_top-5-accuracy: 0.9200
# Epoch 73/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.5272 - accuracy: 0.8117 - top-5-accuracy: 0.9651 - val_loss: 1.8671 - val_accuracy: 0.7120 - val_top-5-accuracy: 0.9100
# Epoch 74/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.5381 - accuracy: 0.8101 - top-5-accuracy: 0.9647 - val_loss: 1.8640 - val_accuracy: 0.7000 - val_top-5-accuracy: 0.9180
# Epoch 75/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.5337 - accuracy: 0.8093 - top-5-accuracy: 0.9645 - val_loss: 1.8727 - val_accuracy: 0.7240 - val_top-5-accuracy: 0.9040
# Epoch 76/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.5294 - accuracy: 0.8144 - top-5-accuracy: 0.9660 - val_loss: 1.7984 - val_accuracy: 0.7260 - val_top-5-accuracy: 0.9340
# Epoch 77/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.5119 - accuracy: 0.8190 - top-5-accuracy: 0.9688 - val_loss: 1.8231 - val_accuracy: 0.7300 - val_top-5-accuracy: 0.9120
# Epoch 78/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.5219 - accuracy: 0.8155 - top-5-accuracy: 0.9649 - val_loss: 1.9250 - val_accuracy: 0.6820 - val_top-5-accuracy: 0.9140
# Epoch 79/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.5122 - accuracy: 0.8211 - top-5-accuracy: 0.9689 - val_loss: 1.9021 - val_accuracy: 0.6780 - val_top-5-accuracy: 0.9080
# Epoch 80/100
# 630/630 [==============================] - 50s 80ms/step - loss: 1.5154 - accuracy: 0.8218 - top-5-accuracy: 0.9669 - val_loss: 1.9578 - val_accuracy: 0.6860 - val_top-5-accuracy: 0.9040
# Epoch 81/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.5285 - accuracy: 0.8118 - top-5-accuracy: 0.9641 - val_loss: 1.9117 - val_accuracy: 0.7100 - val_top-5-accuracy: 0.9060
# Epoch 82/100
# 630/630 [==============================] - 51s 82ms/step - loss: 1.5095 - accuracy: 0.8205 - top-5-accuracy: 0.9690 - val_loss: 1.8299 - val_accuracy: 0.7340 - val_top-5-accuracy: 0.9180
# Epoch 83/100
# 630/630 [==============================] - 51s 80ms/step - loss: 1.5134 - accuracy: 0.8206 - top-5-accuracy: 0.9686 - val_loss: 1.7638 - val_accuracy: 0.7600 - val_top-5-accuracy: 0.9240
# Epoch 84/100
# 630/630 [==============================] - 53s 84ms/step - loss: 1.5029 - accuracy: 0.8214 - top-5-accuracy: 0.9705 - val_loss: 1.8337 - val_accuracy: 0.6920 - val_top-5-accuracy: 0.9220
# Epoch 85/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.4964 - accuracy: 0.8243 - top-5-accuracy: 0.9697 - val_loss: 1.7950 - val_accuracy: 0.7400 - val_top-5-accuracy: 0.9180
# Epoch 86/100
# 630/630 [==============================] - 50s 79ms/step - loss: 1.4841 - accuracy: 0.8329 - top-5-accuracy: 0.9675 - val_loss: 1.8424 - val_accuracy: 0.7300 - val_top-5-accuracy: 0.9260
# Epoch 87/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.4911 - accuracy: 0.8283 - top-5-accuracy: 0.9699 - val_loss: 1.9045 - val_accuracy: 0.7360 - val_top-5-accuracy: 0.9120
# Epoch 88/100
# 630/630 [==============================] - 51s 80ms/step - loss: 1.5016 - accuracy: 0.8256 - top-5-accuracy: 0.9686 - val_loss: 1.9261 - val_accuracy: 0.7120 - val_top-5-accuracy: 0.9060
# Epoch 89/100
# 630/630 [==============================] - 53s 84ms/step - loss: 1.4887 - accuracy: 0.8272 - top-5-accuracy: 0.9697 - val_loss: 1.8554 - val_accuracy: 0.7260 - val_top-5-accuracy: 0.9160
# Epoch 90/100
# 630/630 [==============================] - 52s 82ms/step - loss: 1.4762 - accuracy: 0.8310 - top-5-accuracy: 0.9706 - val_loss: 1.8416 - val_accuracy: 0.7200 - val_top-5-accuracy: 0.9220
# Epoch 91/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.4853 - accuracy: 0.8315 - top-5-accuracy: 0.9689 - val_loss: 1.9115 - val_accuracy: 0.7340 - val_top-5-accuracy: 0.9060
# Epoch 92/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.4876 - accuracy: 0.8298 - top-5-accuracy: 0.9727 - val_loss: 1.9227 - val_accuracy: 0.6900 - val_top-5-accuracy: 0.9020
# Epoch 93/100
# 630/630 [==============================] - 50s 80ms/step - loss: 1.4895 - accuracy: 0.8332 - top-5-accuracy: 0.9712 - val_loss: 1.8253 - val_accuracy: 0.7360 - val_top-5-accuracy: 0.9200
# Epoch 94/100
# 630/630 [==============================] - 52s 83ms/step - loss: 1.4865 - accuracy: 0.8310 - top-5-accuracy: 0.9705 - val_loss: 1.8035 - val_accuracy: 0.7180 - val_top-5-accuracy: 0.9220
# Epoch 95/100
# 630/630 [==============================] - 53s 84ms/step - loss: 1.4661 - accuracy: 0.8360 - top-5-accuracy: 0.9728 - val_loss: 1.8387 - val_accuracy: 0.7180 - val_top-5-accuracy: 0.9220
# Epoch 96/100
# 630/630 [==============================] - 51s 81ms/step - loss: 1.4687 - accuracy: 0.8375 - top-5-accuracy: 0.9719 - val_loss: 1.8515 - val_accuracy: 0.7220 - val_top-5-accuracy: 0.9240
# Epoch 97/100
# 630/630 [==============================] - 52s 83ms/step - loss: 1.4644 - accuracy: 0.8398 - top-5-accuracy: 0.9732 - val_loss: 1.8226 - val_accuracy: 0.7300 - val_top-5-accuracy: 0.9100
# Epoch 98/100
# 630/630 [==============================] - 51s 80ms/step - loss: 1.4630 - accuracy: 0.8385 - top-5-accuracy: 0.9737 - val_loss: 1.8305 - val_accuracy: 0.7220 - val_top-5-accuracy: 0.9200
# Epoch 99/100
# 630/630 [==============================] - 53s 83ms/step - loss: 1.4752 - accuracy: 0.8357 - top-5-accuracy: 0.9721 - val_loss: 1.8265 - val_accuracy: 0.7240 - val_top-5-accuracy: 0.9140
# Epoch 100/100
# 630/630 [==============================] - 51s 80ms/step - loss: 1.4802 - accuracy: 0.8322 - top-5-accuracy: 0.9718 - val_loss: 1.8552 - val_accuracy: 0.7220 - val_top-5-accuracy: 0.9180

# %%
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
loss, accuracy, top_5_accuracy = model.evaluate(test)
print(f"Test loss: {round(loss, 2)}")
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")
# Out:
# 25/25 [==============================] - 174s 7s/step - loss: 1.8317 - accuracy: 0.7140 - top-5-accuracy: 0.9120
# Test loss: 1.83
# Test accuracy: 71.4%
# Test top 5 accuracy: 91.2%
